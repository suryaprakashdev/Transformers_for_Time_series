# %%
#to check for versions in case of error

'''
# %python -m pip install pandas==2.0.3
# %python -m pip install numpy==1.24.3
'''

# %%
#needed to be installed

# %python -m pip install fastparquet
# %python -m pip install -U dtaidistance==2.3.11
#%python -m pip install -v --upgrade --force-reinstall --no-build-isolation --no-binary dtaidistance dtaidistance
# %python -m pip install threadpoolctl==3.1.0
# %python -m pip install scikit-learn==1.3.2
# %python -m pip install tsai==0.3.8
# %python -m pip install fastai==2.7.13
